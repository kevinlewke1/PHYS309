# %% [markdown]
# # Numerically solving the Schrodinger equation
#
# In this assignment you will use [<tt>qmsolve</tt>](https://github.com/quantum-visualizations/qmsolve) to solve the time-independent Schrodinger equation in one dimension and plot the solutions.
#
# ### First, install <tt>qmsolve</tt> in one of two ways:
# <ul>
#     <li>From a <tt>unix</tt> command line, type <tt>pip install qmsolve</tt></li>
#     <li>Put the following commands in a code cell in this notebook and execute:<br />
#         <tt>import sys</tt><br />
#         <tt>!{sys.executable} -m pip install qmsolve</tt></li>
# </ul>

# %%
import sys
# !{sys.executable} -m pip install qmsolve
# Out:
# Requirement already satisfied: qmsolve in ./Desktop/anaconda3/lib/python3.12/site-packages (2.0.0)
# Requirement already satisfied: numpy in ./Desktop/anaconda3/lib/python3.12/site-packages (from qmsolve) (1.26.4)
# Requirement already satisfied: scipy in ./Desktop/anaconda3/lib/python3.12/site-packages (from qmsolve) (1.13.1)
# Requirement already satisfied: matplotlib in ./Desktop/anaconda3/lib/python3.12/site-packages (from qmsolve) (3.9.2)
# Requirement already satisfied: h5py in ./Desktop/anaconda3/lib/python3.12/site-packages (from qmsolve) (3.11.0)
# Requirement already satisfied: progressbar in ./Desktop/anaconda3/lib/python3.12/site-packages (from qmsolve) (2.5)
# Requirement already satisfied: contourpy>=1.0.1 in ./Desktop/anaconda3/lib/python3.12/site-packages (from matplotlib->qmsolve) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in ./Desktop/anaconda3/lib/python3.12/site-packages (from matplotlib->qmsolve) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in ./Desktop/anaconda3/lib/python3.12/site-packages (from matplotlib->qmsolve) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./Desktop/anaconda3/lib/python3.12/site-packages (from matplotlib->qmsolve) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in ./Desktop/anaconda3/lib/python3.12/site-packages (from matplotlib->qmsolve) (24.1)
# Requirement already satisfied: pillow>=8 in ./Desktop/anaconda3/lib/python3.12/site-packages (from matplotlib->qmsolve) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in ./Desktop/anaconda3/lib/python3.12/site-packages (from matplotlib->qmsolve) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in ./Desktop/anaconda3/lib/python3.12/site-packages (from matplotlib->qmsolve) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in ./Desktop/anaconda3/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib->qmsolve) (1.16.0)

# %% [markdown]
# ### Homework problems:
#
# <ol start=0>
#     <li>Follow the link to the <tt>qmsolve</tt> GitHub page above. Click the link for the <tt>examples</tt> folder, then click on the <tt>eigenstate solver examples</tt> folder. Finally, click on <tt>1D_harmonic_oscillator.py</tt> to see a short code snippet that will calculate wavefunctions for a simple harmonic oscillator (SHO).</li>
#     <li><tt>1D_harmonic_oscillator.py</tt> imports the <tt>Hamiltonian</tt> class from <tt>qmsolve</tt>. In quantum mechanics, what is a Hamiltonian? Please use multiple sources to formulate your answer and cite those sources. For this problem, crowd-sourced references such as Wikipedia and stackexchange are acceptable.</li>
#     <li>Which force law is defined in the function <tt>harmonic_oscillator()</tt> in cell 2 of this notebook?</li>
#     <li>What are the eigenstates referred to in lines 22 and 23 in <tt>1D_harmonic_oscillator.py</tt>? Again, please use multiple sources to formulate your answer and cite those sources.
#     <li>Code cells 1 and 2 below contain imported code from <tt>1D_harmonic_oscillator.py</tt>, including a visualization of eigenstate 0 of the SHO. In subsequent code cells, plot any five SHO eigenstates of your choice.</li>
# </ol>
#
# Note: you can write your answers to the non-code problems in a markdown cell. From within a new notebook cell, click the box with a double arrow that says "Code" and change to "Markdown". Then you can just type in the cell like a regular text file.

# %% [markdown]
# 1. The Hamiltonian represents the total energy of a system, including both kinetic and potential energy. It plays a huge role in the Schrodinger equation, where it determines how quantum states evolve over time. H_hatψ=Eψ. H_hat is the hamiltonian variable and psi is a wavefunction. https://en.wikipedia.org/wiki/Hamiltonian_(quantum_mechanics)  https://www.quera.com/glossary/hamiltonian
# 2. The force law defined in the function harmonic_oscillator() is Hookes Law.
# 3. Those lines are computing the eigenstates and eigenenergies of the systems Hamiltonian. Eigenstates are the solutions psi_n(x) to the time dependent Schrodinger equation. Each eigenstate corresponds to a quantum state with a specific energy level, a wave function shape that includes a zero crossing, and orthogonality and normilization properties . These eigenstates represent the only physically allowable stationary states of the SHO under the potential defined by Hooke’s law. https://en.wikipedia.org/wiki/Quantum_harmonic_oscillator https://www.fisica.net/mecanica-quantica/Griffiths%20-%20Introduction%20to%20quantum%20mechanics.pdf.
# 4.

# %%
import sys
# !{sys.executable} -m pip install qmsolve
# Out:
# Collecting qmsolve
#   Downloading qmsolve-2.0.0-py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: numpy in ./Desktop/anaconda3/lib/python3.12/site-packages (from qmsolve) (1.26.4)
# Requirement already satisfied: scipy in ./Desktop/anaconda3/lib/python3.12/site-packages (from qmsolve) (1.13.1)
# Requirement already satisfied: matplotlib in ./Desktop/anaconda3/lib/python3.12/site-packages (from qmsolve) (3.9.2)
# Requirement already satisfied: h5py in ./Desktop/anaconda3/lib/python3.12/site-packages (from qmsolve) (3.11.0)
# Collecting progressbar (from qmsolve)
#   Downloading progressbar-2.5.tar.gz (10 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: contourpy>=1.0.1 in ./Desktop/anaconda3/lib/python3.12/site-packages (from matplotlib->qmsolve) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in ./Desktop/anaconda3/lib/python3.12/site-packages (from matplotlib->qmsolve) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in ./Desktop/anaconda3/lib/python3.12/site-packages (from matplotlib->qmsolve) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./Desktop/anaconda3/lib/python3.12/site-packages (from matplotlib->qmsolve) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in ./Desktop/anaconda3/lib/python3.12/site-packages (from matplotlib->qmsolve) (24.1)
# Requirement already satisfied: pillow>=8 in ./Desktop/anaconda3/lib/python3.12/site-packages (from matplotlib->qmsolve) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in ./Desktop/anaconda3/lib/python3.12/site-packages (from matplotlib->qmsolve) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in ./Desktop/anaconda3/lib/python3.12/site-packages (from matplotlib->qmsolve) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in ./Desktop/anaconda3/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib->qmsolve) (1.16.0)
# Downloading qmsolve-2.0.0-py3-none-any.whl (35 kB)
# Building wheels for collected packages: progressbar
#   Building wheel for progressbar (setup.py) ... done
#   Created wheel for progressbar: filename=progressbar-2.5-py3-none-any.whl size=12066 sha256=5812310a16959938b127ab4c07ba9569cd8b194285adb31c4d50c5e932935698
#   Stored in directory: /Users/kevinlewke/Library/Caches/pip/wheels/a5/4d/c7/f3cf0f75c746c219090060131fe00f1523cc2c5484991f4030
# Successfully built progressbar
# Installing collected packages: progressbar, qmsolve
# Successfully installed progressbar-2.5 qmsolve-2.0.0

# %%
import numpy as np
import matplotlib.pyplot as plt

from qmsolve import Hamiltonian, SingleParticle, init_visualization, Å, eV

# %%
# Harmonic oscillator potential
def harmonic_oscillator(particle):
    k = 100 * eV / Å**2
    return 0.5 * k * particle.x**2

# Define the Hamiltonian
H = Hamiltonian(particles = SingleParticle(), potential = harmonic_oscillator, 
                spatial_ndim = 1, N = 512, extent = 20*Å)

#Diagonalize the Hamiltonian and compute the eigenstates
eigenstates = H.solve(max_states = 30)

# Print out the energies of the eigenstates
print(eigenstates.energies) # the printed energies are expressed in eV

# Visualize the Eigenstates
visualization = init_visualization(eigenstates)
visualization.plot_eigenstate(0)
# Out:
# Computing...
# Took 0.7837667465209961
# [ 13.8243627   41.46350403  69.08346722  96.68423227 124.26577906
#  151.82808744 179.37113718 206.89490796 234.39937942 261.8845311
#  289.35034249 316.79679298 344.22386192 371.63152856 399.01977209
#  426.38857162 453.73790619 481.06775475 508.3780962  535.66890934
#  562.9401729  590.19186555 617.42396585 644.63645231 671.82930335
#  699.00249732 726.15601246 753.28982697 780.40391895 807.49826642]

# %%
import numpy as np
import matplotlib.pyplot as plt

from qmsolve import Hamiltonian, SingleParticle, init_visualization, Å, eV

def harmonic_oscillator(particle):
    k = 100 * eV / Å**2
    return 0.5 * k * particle.x**2

H = Hamiltonian(particles = SingleParticle(), potential = harmonic_oscillator, 
                spatial_ndim = 1, N = 512, extent = 20*Å)

eigenstates = H.solve(max_states=30)

visualization = init_visualization(eigenstates)

visualization.plot_eigenstate(0)
visualization.plot_eigenstate(1)
visualization.plot_eigenstate(2)
visualization.plot_eigenstate(3)
visualization.plot_eigenstate(4)
# Out:
# Computing...
# Took 0.0713801383972168

# %% [markdown]
# <ol start=5>
#     <li>What is on the x-axis of your plots?</li>
#     <li>Are your plots showing wave functions $\psi(x)$ or probability functions $\psi^*(x) \psi(x)$? How do you know?</li>
# </ol>
#
# ### New potential: infinite square well
#
# Below I define the infinite square well potential and plot the two lowest-energy eigenstates (compare to Figure 6.3 in your textbook).

# %% [markdown]
# 5. The x axis of my plots represent the position of the particles.
# 6. The plots are showing wave functions. This is because the plotted function contains both postive and negative values, which a probability function can not be negative. Also, looking at the plots visually, you can tell that they don't resemble a probability function but a wave function, yes.

# %%
# 8 angstrom-wide infinite square well
def infinite_square_well(particle):
    potential = np.zeros_like(particle.x)
    out_of_bounds = np.abs(particle.x) > 4*Å
    potential[out_of_bounds] = np.inf
    return potential

# Define the Hamiltonian of the infinite square well
H_sw = Hamiltonian(particles = SingleParticle(), potential = infinite_square_well, 
                   spatial_ndim = 1, N = 512, extent = 10*Å)

# Diagonalize the Hamiltonian and compute the eigenstates
eigenstates_sw = H_sw.solve(max_states = 30)

print(eigenstates_sw.energies)

# Visualize the infinite square well eigenstates
visualization_sw = init_visualization(eigenstates_sw)
visualization_sw.plot_eigenstate(0)
visualization_sw.plot_eigenstate(1)
visualization_sw.plot_eigenstate(2)
visualization_sw.plot_eigenstate(3)
visualization_sw.plot_eigenstate(4)
# Out:
# Computing...
# Took 0.08308196067810059
# [  0.58926935   2.35704264   5.30321556   9.4276143   14.7299955
#   21.21004635  28.8673845   37.70155819  47.71204619  58.89825789
#   71.2595333   84.79514311  99.50428872 115.3861023  132.43964681
#  150.6639161  170.05783494 190.6202591  212.34997539 235.24570176
#  259.30608737 284.52971266 310.91508944 338.46066097 367.16480207
#  397.0258192  428.04195057 460.21136622 493.53216816 528.00239048]

# %% [markdown]
# <ol start=7>
#     <li>Plot any three infinite square well eigenstates of your choice.</li>
#     <li>What property do the infinite square well eigenstates have that's different than the SHO eigenstates? (Hint: think about the properties of valid wave functions we discussed in class)</li>
#     <li>What is the relationship between the number of extrema (maxima plus minima) in each eigenstate plot and the quantum number of the eigenstate?</li>
# </ol>

# %% [markdown]
# 8. One difference is the infinite square well eigenstates are exactly zero at the boundaries of the well. This is because the potential at the wall are infinite, so the particle has a zero probability of being outside the well. The SHO eigenstates wavefunctions decay gradually toward zero but they never become exactly zero at a finite point.
# 9. The number of extrema in each eigenstate is equal to the quantum number n+1. This happens because the wavefunctions in an infinite square well are sine functions that fit exactly in well. Each increase in n adds one more half wavelength inside the well, which increases the number of turning points.

# %% [markdown]
# ### Now it's your turn to define a potential
#
# <ol start=10>
#     <li>Write a function that defines a <em>finite square-well</em> potential (textbook section 5.4). You can choose the width of the well in Angstroms and the potential at the walls in eV. Calculate the finite square-well Hamiltonian and plot any five eigenstates you choose.</li>
#     <li>Based on your plots, do you think a particle can get out of the finite square-well potential no matter its quantum number $n$?</li>
# </ol>

# %%
from qmsolve import Hamiltonian, SingleParticle, init_visualization, eV, Å
import numpy as np

def finite_square_well(particle):
    V0 = 20 * eV           
    width = 8 * Å          
    V = V0 * np.ones_like(particle.x)
    inside = np.abs(particle.x) < (width/2)
    V[inside] = 0          
    return V

H_fsw = Hamiltonian(particles=SingleParticle(), potential=finite_square_well, spatial_ndim=1, extent=15*Å, N=512)

eigenstates_fsw = H_fsw.solve(max_states=10)

visualization_fsw = init_visualization(eigenstates_fsw)
visualization_fsw.plot_eigenstate(0)
visualization_fsw.plot_eigenstate(1)
visualization_fsw.plot_eigenstate(2)
visualization_fsw.plot_eigenstate(3)
visualization_fsw.plot_eigenstate(4)
# Out:
# Computing...
# Took 0.03886675834655762

# %% [markdown]
# 11. Based on the plots, a particle can't stay trapped inside the well. For low quantum numbers, the particles energy is below the height of the potential walls. In our case, the particle is bounded inside the well. However, if the quantum number is large, the partcles energy gets higher, and onces it reaches a specific point, the particle can escape because it is no longer bounded.
